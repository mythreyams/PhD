# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.interpolate import UnivariateSpline
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
# read the neuron positions data frame
file = 'Y:/V10/Registration/Outputs/Neuron_Position_and_Angles.csv'
df = pd.read_csv(file)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Exp', 'Soma_Center_X', 'Soma_Center_Y', 'Soma_Center_Z',
#        'Distance_of_Soma_From_Center_3D', 'Angle_of_Soma_From_X_Axis',
#        'Angle_of_Soma_From_Z_Axis', 'Distance_To_Nearest_Axis_XY',
#        'Cortical_Thickness_As_Per_Neuron_Axis',
#        'Cortical_Thickness_As_Per_Avg_Local_Axis',
#        'Cortical_Thickness_As_Per_Nearest_Axis_in_Avg_Surface',
#        'Thickness_Difference_From_Neuron_Axis',
#        'Thickness_Difference_From_Neuron_Axis_Local_Avg',
#        'Angle_Between_Neuron_Axis_And_Local_Avg_Axis_Original',
#        'Angle_Between_Neuron_Axis_And_Nearest_Axis'],
#       dtype='object')

# %%
df.dropna()
sum(abs(df['Thickness_Difference_From_Neuron_Axis'])<400) / 90
# Out:
# 0.7444444444444445

# %%
fig = plt.figure(figsize=(8,6))
ax1 = fig.add_subplot(121, projection='3d')
ax2 = fig.add_subplot(122, projection='3d')

xs = df['Soma_Center_X']
ys = -df['Soma_Center_Y']
zs1 = abs(df['Thickness_Difference_From_Neuron_Axis'])
zs2 = df['Cortical_Thickness_As_Per_Nearest_Axis_in_Avg_Surface']
ax1.scatter(xs, ys, zs1,  alpha=0.6, edgecolors='w')
ax2.scatter(xs, ys, zs2,  alpha=0.6, edgecolors='w')

ax1.set_xlabel('Soma_Center_X')
ax1.set_ylabel('Soma_Center_Y')
ax1.set_zlabel('Thickness_Difference_From_Neuron_Axis')

ax2.set_xlabel('Soma_Center_X')
ax2.set_ylabel('Soma_Center_Y')
ax2.set_zlabel('Cortical_Thickness_As_Per_Nearest_Axis_in_Avg_Surface')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_subplot(121, projection='3d')
ax1.bar3d(xs, ys, np.zeros_like(zs), 10, 10, zs, shade=True)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
np.zeros_like
# Out:
# <function numpy.zeros_like(a, dtype=None, order='K', subok=True)>
